# %%
import numpy as np
import pandas as pd

# %%
data = pd.read_csv('Churn_Modelling.csv')

# %%
data.head()
# Out:
#    RowNumber  CustomerId   Surname  CreditScore Geography  Gender  Age  \
# 0          1    15634602  Hargrave          619    France  Female   42
# 1          2    15647311      Hill          608     Spain  Female   41
# 2          3    15619304      Onio          502    France  Female   42
# 3          4    15701354      Boni          699    France  Female   39
# 4          5    15737888  Mitchell          850     Spain  Female   43
#
#    Tenure    Balance  NumOfProducts  HasCrCard  IsActiveMember  \
# 0       2       0.00              1          1               1
# 1       1   83807.86              1          0               1
# 2       8  159660.80              3          1               0
# 3       1       0.00              2          0               0
# 4       2  125510.82              1          1               1
#
#    EstimatedSalary  Exited
# 0        101348.88       1
# 1        112542.58       0
# 2        113931.57       1
# 3         93826.63       0
# ...

# %%
data = data.drop(columns = ['RowNumber','CustomerId','Surname','Geography','Gender'])
data.head()
# Out:
#    CreditScore  Age  Tenure    Balance  NumOfProducts  HasCrCard  \
# 0          619   42       2       0.00              1          1
# 1          608   41       1   83807.86              1          0
# 2          502   42       8  159660.80              3          1
# 3          699   39       1       0.00              2          0
# 4          850   43       2  125510.82              1          1
#
#    IsActiveMember  EstimatedSalary  Exited
# 0               1        101348.88       1
# 1               1        112542.58       0
# 2               0        113931.57       1
# 3               0         93826.63       0
# 4               1         79084.10       0

# %%
X = data.iloc[:,:-1].values
y = data.iloc[:, -1].values

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size = 0.2, random_state = 0)

# %%
from sklearn.preprocessing import StandardScaler
sc = StandardScaler()
X_train = sc.fit_transform(X_train)
X_test = sc.transform(X_test)

# %%
from Gradient_descent import Gradient_descent

obj = Gradient_descent()
total_lost_list, w_list, b = obj.gradient_descent(X_train = X_train, y_train = y_train, epochs = 1000, learning_rate = 0.01)
# Out:
# Epoch(0 / 1000): Error ---> 0.693147
#
#
# Epoch(1 / 1000): Error ---> 0.692074
#
#
# Epoch(2 / 1000): Error ---> 0.691006
#
#
# Epoch(3 / 1000): Error ---> 0.689944
#
#
# Epoch(4 / 1000): Error ---> 0.688887
#
#
# Epoch(5 / 1000): Error ---> 0.687835
#
#
# Epoch(6 / 1000): Error ---> 0.686789
#
#
# Epoch(7 / 1000): Error ---> 0.685748
#
#
# Epoch(8 / 1000): Error ---> 0.684712
#
#
# Epoch(9 / 1000): Error ---> 0.683681
#
#
# Epoch(10 / 1000): Error ---> 0.682655
#
#
# Epoch(11 / 1000): Error ---> 0.681634
#
#
# Epoch(12 / 1000): Error ---> 0.680619
#
#
# Epoch(13 / 1000): Error ---> 0.679608
#
#
# Epoch(14 / 1000): Error ---> 0.678603
#
#
# Epoch(15 / 1000): Error ---> 0.677603
#
#
# Epoch(16 / 1000): Error ---> 0.676607
#
#
# Epoch(17 / 1000): Error ---> 0.675617
#
#
# Epoch(18 / 1000): Error ---> 0.674631
#
#
# Epoch(19 / 1000): Error ---> 0.673651
#
#
# Epoch(20 / 1000): Error ---> 0.672675
#
#
# Epoch(21 / 1000): Error ---> 0.671704
#
#
# Epoch(22 / 1000): Error ---> 0.670738
#
# ...

# %%
import matplotlib.pyplot as plt
plt.plot(total_lost_list)
